# %%
# !pip install transformers
# !pip install gradio
# !pip install timm
# !pip install torchvision
# Out:
# Requirement already satisfied: transformers in d:\software_install\anaconda3\envs\torch\lib\site-packages (4.41.2)
# Requirement already satisfied: filelock in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.1)
# Requirement already satisfied: colorama in d:\software_install\anaconda3\envs\torch\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: gradio in d:\software_install\anaconda3\envs\torch\lib\site-packages (4.32.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.17.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.17.0)
# Requirement already satisfied: httpx>=0.24.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.23.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (3.6.2)
# Requirement already satisfied: numpy~=1.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (3.10.3)
# Requirement already satisfied: packaging in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (9.3.0)
# Requirement already satisfied: pydantic>=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (2.7.2)
# Requirement already satisfied: pydub in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.4.7)
# Requirement already satisfied: semantic-version~=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (4.12.1)
# Requirement already satisfied: urllib3~=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio) (0.30.1)
# Requirement already satisfied: fsspec in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio-client==0.17.0->gradio) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from gradio-client==0.17.0->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.22.0)
# Requirement already satisfied: toolz in d:\software_install\anaconda3\envs\torch\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpx>=0.24.1->gradio) (4.4.0)
# Requirement already satisfied: certifi in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpx>=0.24.1->gradio) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.64.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from pydantic>=2.0->gradio) (2.18.3)
# Requirement already satisfied: click>=8.0.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from fastapi->gradio) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from fastapi->gradio) (2.1.1)
# Requirement already satisfied: colorama in d:\software_install\anaconda3\envs\torch\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: six>=1.5 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: httptools>=0.5.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.1.1)
# Requirement already satisfied: mdurl~=0.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Collecting timm
#   Downloading timm-1.0.9-py3-none-any.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.4 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.4 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 42.4/42.4 kB 684.3 kB/s eta 0:00:00
# Requirement already satisfied: torch in d:\software_install\anaconda3\envs\torch\lib\site-packages (from timm) (2.1.2+cu118)
# Requirement already satisfied: torchvision in d:\software_install\anaconda3\envs\torch\lib\site-packages (from timm) (0.16.2+cu118)
# Requirement already satisfied: pyyaml in d:\software_install\anaconda3\envs\torch\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in d:\software_install\anaconda3\envs\torch\lib\site-packages (from timm) (0.23.2)
# Requirement already satisfied: safetensors in d:\software_install\anaconda3\envs\torch\lib\site-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (23.2)
# Requirement already satisfied: requests in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from huggingface_hub->timm) (4.12.1)
# Requirement already satisfied: sympy in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch->timm) (3.0)
# Requirement already satisfied: jinja2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch->timm) (3.1.2)
# Requirement already satisfied: numpy in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision->timm) (9.3.0)
# Requirement already satisfied: colorama in d:\software_install\anaconda3\envs\torch\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jinja2->torch->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->huggingface_hub->timm) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->huggingface_hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->huggingface_hub->timm) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->huggingface_hub->timm) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from sympy->torch->timm) (1.3.0)
# Downloading timm-1.0.9-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.3 MB 1.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.3 MB 4.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.3 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.3 MB 9.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.3 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.3 MB 9.1 MB/s eta 0:00:01
#    --------------------------------- ------ 2.0/2.3 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: timm
# Successfully installed timm-1.0.9
# Requirement already satisfied: torchvision in d:\software_install\anaconda3\envs\torch\lib\site-packages (0.16.2+cu118)
# Requirement already satisfied: numpy in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: torch==2.1.2+cu118 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision) (2.1.2+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: filelock in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (3.9.0)
# Requirement already satisfied: typing-extensions in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (4.12.1)
# Requirement already satisfied: sympy in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (1.12)
# Requirement already satisfied: networkx in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (3.0)
# Requirement already satisfied: jinja2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in d:\software_install\anaconda3\envs\torch\lib\site-packages (from torch==2.1.2+cu118->torchvision) (2024.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->torchvision) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from jinja2->torch==2.1.2+cu118->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in d:\software_install\anaconda3\envs\torch\lib\site-packages (from sympy->torch==2.1.2+cu118->torchvision) (1.3.0)

# %%
from transformers.utils import logging
logging.set_verbosity_error()

# %%
from transformers import pipeline
sam_pipe = pipeline("mask-generation",
    "./models/Zigeng/SlimSAM-uniform-77")
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File d:\software_install\anaconda3\envs\torch\Lib\site-packages\transformers\utils\hub.py:399, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     397 try:
#     398     # Load from URL or cache if already cached
# --> 399     resolved_file = hf_hub_download(
#     400         path_or_repo_id,
#     401         filename,
#     402         subfolder=None if len(subfolder) == 0 else subfolder,
#     403         repo_type=repo_type,
#     404         revision=revision,
#     405         cache_dir=cache_dir,
#     406         user_agent=user_agent,
#     407         force_download=force_download,
#     408         proxies=proxies,
#     409         resume_download=resume_download,
#     410         token=token,
#     411         local_files_only=local_files_only,
#     412     )
#     413 except GatedRepoError as e:
#
# File d:\software_install\anaconda3\envs\torch\Lib\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File d:\software_install\anaconda3\envs\torch\Lib\site-packages\huggingface_hub\utils\_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './models/Zigeng/SlimSAM-uniform-77'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 2
#       1 from transformers import pipeline
# ----> 2 sam_pipe = pipeline("mask-generation",
#       3     "./models/Zigeng/SlimSAM-uniform-77")
#
# File d:\software_install\anaconda3\envs\torch\Lib\site-packages\transformers\pipelines\__init__.py:779, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     775     pretrained_model_name_or_path = model
#     777 if not isinstance(config, PretrainedConfig) and pretrained_model_name_or_path is not None:
#     778     # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 779     resolved_config_file = cached_file(
#     780         pretrained_model_name_or_path,
#     781         CONFIG_NAME,
#     782         _raise_exceptions_for_gated_repo=False,
#     783         _raise_exceptions_for_missing_entries=False,
#     784         _raise_exceptions_for_connection_errors=False,
#     785         cache_dir=model_kwargs.get("cache_dir"),
#     786         **hub_kwargs,
#     787     )
#     788     hub_kwargs["_commit_hash"] = extract_commit_hash(resolved_config_file, commit_hash)
#     789 else:
#
# File d:\software_install\anaconda3\envs\torch\Lib\site-packages\transformers\utils\hub.py:463, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     461     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     462 except HFValidationError as e:
# --> 463     raise EnvironmentError(
#     464         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     465     ) from e
#     466 return resolved_file
#
# OSError: Incorrect path_or_model_id: './models/Zigeng/SlimSAM-uniform-77'. Please provide either the path to a local folder or the repo_id of a model on the Hub.
